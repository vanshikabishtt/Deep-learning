# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
data = pd.read_csv("/content/IMDB Dataset.csv.zip")
texts = data['review']
labels = data['sentiment'].map({'positive':1, 'negative':0})

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(texts)

sequences = tokenizer.texts_to_sequences(texts)
X = pad_sequences(sequences, maxlen=100)
y = np.array(labels)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
model = Sequential()
model.add(Embedding(input_dim=5000, output_dim=32, input_length=100))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 26ms/step - accuracy: 0.7639 - loss: 0.4675 - val_accuracy: 0.8479 - val_loss: 0.3527
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.8697 - loss: 0.3151 - val_accuracy: 0.8533 - val_loss: 0.3399
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.8913 - loss: 0.2729 - val_accuracy: 0.8525 - val_loss: 0.3709
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.9183 - loss: 0.2125 - val_accuracy: 0.8370 - val_loss: 0.3914
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.9448 - loss: 0.1527 - val_accuracy: 0.8377 - val_loss: 0.4546
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.9629 - loss: 0.1071 - val_accuracy: 0.8306 - val_loss: 0.5457
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.9749 - loss: 0.0755 - val_accuracy: 0.8341 - val_loss: 0.6562
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.9847 - loss: 0.0508 - val_accuracy: 0.8276 - val_loss: 0.7462
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 25ms/step - accuracy: 0.9851 - loss: 0.0451 - val_accuracy: 0.8187 - val_loss: 0.8192
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 16s 26ms/step - accuracy: 0.9886 - loss: 0.0360 - val_accuracy: 0.8089 - val_loss: 0.8577

# %%
sample = ["This movie was amazing"]
seq = tokenizer.texts_to_sequences(sample)
pad = pad_sequences(seq, maxlen=100)

prediction = model.predict(pad)
print("Positive" if prediction > 0.5 else "Negative")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Positive
